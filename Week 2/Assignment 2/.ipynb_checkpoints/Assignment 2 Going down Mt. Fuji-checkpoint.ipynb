# %% [markdown]
# Assignment 2 Going down Mt. Fuji
#
# Student: Nguyễn Tấn Tài

# %% [markdown]
# Problem 1: Visualization of data

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load csv data
csv_path = "mtfuji_data.csv"
np.set_printoptions(suppress = True)
fuji = np.loadtxt(csv_path, delimiter = ",", skiprows = 1)

plt.plot(fuji[:,0], fuji[:,3])
plt.title("Mt. Fuji")
plt.xlabel("Position")
plt.ylabel("Elevation[m]")

plt.show()

# %% [markdown]
# Problem 2: Create a function to calculate the slope of a point

# %%
# Function to get radient at pos (pos > 1)
def gradient_calculate(pos):
    change_x = fuji[:,0][1:] - fuji[:,0][:-1]
    change_y = fuji[:,3][1:] - fuji[:,3][:-1]
    gradient = change_y / change_x
    return gradient[pos]

print(gradient_calculate(10))
# Out:
# 6.280000000000001

# %% [markdown]
# Problem 3: Create a function to calculate the destination

# %%
# Function to get next destination
def next_destination(pos):
    # Destination point
    hyper_parameter = 0.2
    destination_point = fuji[:,0][pos] - hyper_parameter * gradient_calculate(pos)
    # Check if value is negative
    if (destination_point < 0):
        return np.nan
    else:
        # Round value
        return round(destination_point)

print(next_destination(10))
# Out:
# 9

# %% [markdown]
# Problem 4: Create a function to go down the mountain

# %%
# First current point is the 136th location
def go_down():
    visited = np.zeros(fuji[:,0].size, dtype = int)
    pos = fuji[:,0][136]
    while (pos != np.nan and visited[int(pos)] != 1):
        visited[int(pos)] = 1
        print("Move from position {} to position {}".format(pos, next_destination(int(pos))))
        pos = next_destination(int(pos))

go_down()
# Out:
# Move from position 136.0 to position 103
# Move from position 103 to position 98
# Move from position 98 to position 95
# Move from position 95 to position 89
# Move from position 89 to position 86
# Move from position 86 to position 83
# Move from position 83 to position 80
# Move from position 80 to position 76
# Move from position 76 to position 74
# Move from position 74 to position 74

# %% [markdown]
# Problem 5: Visualization of the descent process
#
# We marked visited position as red x on the graph

# %%
visited = np.zeros(fuji[:,0].size, dtype = int)
plt.plot(fuji[:,0], fuji[:,3])

pos = fuji[:,0][136]
while (pos != np.nan and visited[int(pos)] != 1):
        visited[int(pos)] = 1
        plt.plot(fuji[:,0][int(pos)], fuji[:,3][int(pos)], 'rx')
        pos = next_destination(int(pos))

plt.title("Mt. Fuji")
plt.xlabel("Position")
plt.ylabel("Elevation[m]")

plt.show()

# %% [markdown]
# Problem 6: Change of initial value
#
# We combined the graph drawing and the function above into one function

# %%
def go_down(start_pos):
    visited = np.zeros(fuji[:,0].size, dtype = int)
    pos = fuji[:,0][start_pos]

    plt.plot(fuji[:,0], fuji[:,3])

    while (pos != np.nan and visited[int(pos)] != 1):
        visited[int(pos)] = 1
        plt.plot(fuji[:,0][int(pos)], fuji[:,3][int(pos)], 'rx')
        print("Move from position {} to position {}".format(pos, next_destination(int(pos))))
        pos = next_destination(int(pos))

    plt.title("Mt. Fuji")
    plt.xlabel("Position")
    plt.ylabel("Elevation[m]")

    plt.show()

go_down(142)
# Out:
# Move from position 142.0 to position 172
# Move from position 172 to position 175
# Move from position 175 to position 176
# Move from position 176 to position 177
# Move from position 177 to position 179
# Move from position 179 to position 185
# Move from position 185 to position 163
# Move from position 163 to position 168
# Move from position 168 to position 172

# %% [markdown]
# Problem 7: (Advance problem) Hyperparameter change

# %% [markdown]
# We modified the next destination and go down functions to include hyperparameter parameter:"

# %%
# Function to get next destination
def next_destination(pos, hyper_parameter = 0.2):
    # Destination point
    destination_point = fuji[:,0][pos] - hyper_parameter * gradient_calculate(pos)
    # Check if value is negative
    if (destination_point < 0):
        return np.nan
    else:
        # Round value
        return round(destination_point)

# Go down function
def go_down(start_pos, hyper_parameter = 0.2):
    visited = np.zeros(fuji[:,0].size, dtype = int)
    pos = fuji[:,0][start_pos]

    plt.plot(fuji[:,0], fuji[:,3])

    while (pos != np.nan and visited[int(pos)] != 1):
        visited[int(pos)] = 1
        plt.plot(fuji[:,0][int(pos)], fuji[:,3][int(pos)], 'rx')
        print("Move from position {} to position {}".format(pos, next_destination(int(pos))))
        pos = next_destination(int(pos), hyper_parameter)

    plt.title("Mt. Fuji")
    plt.xlabel("Position")
    plt.ylabel("Elevation[m]")

    plt.show()

go_down(142, 0.1)
# Out:
# Move from position 142.0 to position 172
# Move from position 157 to position 164
# Move from position 160 to position 171
# Move from position 166 to position 173
# Move from position 170 to position 177
# Move from position 174 to position 177
# Move from position 175 to position 176
